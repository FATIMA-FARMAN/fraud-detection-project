# %% [markdown]
# # 01 — Quick EDA
#
# Use this notebook to quickly explore the synthetic transactions.
#
# Steps:
# 1. Load `data/raw/transactions.csv`
# 2. View schema, missing values, and basic distributions
# 3. Plot amount by hour; fraud rate by merchant category

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data/raw/transactions.csv', parse_dates=['txn_ts'])
df.head()
